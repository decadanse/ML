# %%
import numpy as np
import pandas as pd
# %matplotlib inline

#объединяем содержимое из всех 5-ти файлов в папке
train_data = pd.concat([pd.read_csv("./sf-tree-based-models-for-classification/train/train"+ str(i)+".csv") for i in range(5)], axis=1) 
test_data = pd.concat([pd.read_csv("./sf-tree-based-models-for-classification/test/test"+ str(i)+".csv") for i in range(5)], axis=1)

# %%
train_data
# Out:
#            ID  Category  radius_mean  radius_std  radius_max  texture_mean  \
# 0      857810         0       13.050       19.31       82.61         527.2
# 1    84300903         1       19.690       21.25      130.00        1203.0
# 2       89122         1       19.400       18.18      127.20        1145.0
# 3     8810703         1       28.110       18.47      188.50        2499.0
# 4      904969         0       12.340       14.95       78.29         469.1
# ..        ...       ...          ...         ...         ...           ...
# 279    899187         0       11.660       17.07       73.70         421.0
# 280   9113778         0        9.667       18.49       61.49         289.1
# 281    895633         1       16.260       21.88      107.50         826.8
# 282    902976         0       13.880       16.16       88.37         596.6
# 283   8910721         0       14.290       16.82       90.30         632.6
#
#      texture_std        IT  Category  area_std  ...  texture_max  \
# ...

# %%
train_data.isnull().sum().sum(), test_data.isnull().sum().sum()
# Out:
# (0, 0)
